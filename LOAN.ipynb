# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
loan = pd.read_csv('/content/loan_sanction_test.csv')

# %%
loan
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
loan.shape
# Out:
# (367, 12)

# %%
loan.drop_duplicates()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
loan.isnull().sum().sum()
# Out:
# 84

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
loan['Gender'].fillna(loan['Gender'].mode()[0],inplace=True)

# %%
loan['Self_Employed'].fillna(loan['Self_Employed'].mode()[0],inplace=True)

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
sns.boxplot(loan['Dependents'])
# Out:
# <Axes: ylabel='Dependents'>

# %%
loan['Dependents'].mode()[0]
# Out:
# '0'

# %%
loan['Dependents'].fillna(loan['Dependents'].mode()[0],inplace=True)

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
median_loan_amount = loan['LoanAmount'].median()
median_loan_amount
# Out:
# 125.0

# %%
loan['LoanAmount'].fillna(loan['LoanAmount'].median(),inplace=True)

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
sns.boxplot(loan['LoanAmount'])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
Q1 = loan['LoanAmount'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['LoanAmount'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 101.0
# Q3 is 157.5

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 56.5

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# 16.25
# 242.25

# %%
outliers = loan[(loan['LoanAmount'] < lower_bound) | (loan['LoanAmount'] > upper_bound)]
outliers
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 8    LP001059    Male     Yes          2  Graduate            No
# 18   LP001108    Male     Yes          0  Graduate            No
# 24   LP001149    Male     Yes          0  Graduate            No
# 27   LP001169    Male     Yes          0  Graduate            No
# 81   LP001428    Male     Yes         3+  Graduate            No
# 83   LP001446    Male     Yes          0  Graduate            No
# 91   LP001483    Male     Yes         3+  Graduate            No
# 96   LP001500    Male     Yes          1  Graduate            No
# 124  LP001655  Female      No          0  Graduate            No
# 143  LP001791    Male     Yes          0  Graduate           Yes
# 144  LP001794    Male     Yes          2  Graduate           Yes
# 189  LP002059    Male     Yes          2  Graduate            No
# 194  LP002077    Male     Yes          1  Graduate            No
# ...

# %%
loan['LoanAmount'] = np.where((loan['LoanAmount'] < lower_bound) | (loan['LoanAmount'] > upper_bound), median_loan_amount, loan['LoanAmount'])
print(loan['LoanAmount'])
# Out:
# 0      110.0
# 1      126.0
# 2      208.0
# 3      100.0
# 4       78.0
#        ...
# 362    113.0
# 363    115.0
# 364    126.0
# 365    158.0
# 366     98.0
# Name: LoanAmount, Length: 367, dtype: float64

# %%
sns.boxplot(loan['LoanAmount'])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
Q1 = loan['LoanAmount'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['LoanAmount'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 101.0
# Q3 is 150.0

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 49.0

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# 27.5
# 223.5

# %%
loan['LoanAmount'] = np.where(loan['LoanAmount'] < lower_bound, lower_bound, loan['LoanAmount'])
loan['LoanAmount'] = np.where(loan['LoanAmount'] > upper_bound, upper_bound, loan['LoanAmount'])

# %%
sns.boxplot(loan['LoanAmount'])
plt.show()

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
sns.scatterplot(loan['Loan_Amount_Term'])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
sns.boxplot(loan['Loan_Amount_Term'])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
Q1 = loan['Loan_Amount_Term'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['Loan_Amount_Term'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 360.0
# Q3 is 360.0

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 0.0

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# 360.0
# 360.0

# %%
q = loan[(loan['Loan_Amount_Term'] < lower_bound) | (loan['Loan_Amount_Term'] > upper_bound)]
q
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 8    LP001059    Male     Yes          2      Graduate            No
# 12   LP001083    Male      No         3+      Graduate            No
# 19   LP001115    Male      No          0      Graduate            No
# 21   LP001124  Female      No         3+  Not Graduate            No
# 29   LP001176    Male      No          0      Graduate            No
# 36   LP001208    Male     Yes          2      Graduate            No
# 53   LP001298    Male     Yes          2      Graduate            No
# 57   LP001321    Male     Yes          2      Graduate            No
# 59   LP001324    Male     Yes         3+      Graduate            No
# 72   LP001375    Male     Yes          1      Graduate            No
# 82   LP001445    Male     Yes          2  Not Graduate            No
# 84   LP001450    Male     Yes          0      Graduate            No
# 85   LP001452    Male     Yes          2      Graduate            No
# ...

# %%
median = loan['Loan_Amount_Term'].median()
median
# Out:
# 360.0

# %%
loan['Loan_Amount_Term'] = np.where((loan['Loan_Amount_Term'] < lower_bound) | (loan['Loan_Amount_Term'] > upper_bound), median, loan['Loan_Amount_Term'])
print(loan['Loan_Amount_Term'])
# Out:
# 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 362    360.0
# 363    360.0
# 364    360.0
# 365    360.0
# 366    360.0
# Name: Loan_Amount_Term, Length: 367, dtype: float64

# %%
sns.scatterplot(loan['Loan_Amount_Term'])
plt.show()

# %%
loan['Loan_Amount_Term'] = loan['Loan_Amount_Term'].fillna(median).astype(float)

# %%
sns.boxplot(loan['Loan_Amount_Term'])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
sns.boxplot(loan['Credit_History'])
# Out:
# <Axes: ylabel='Credit_History'>

# %%
credit_median = loan['Credit_History'].median()
credit_median
# Out:
# 1.0

# %%
loan['Credit_History'] = loan['Credit_History'].fillna(loan['Credit_History'].median())
sns.heatmap(loan.isnull())
# Out:
# <Axes: >

# %%
loan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan.isnull().sum().sum()
# Out:
# 0

# %%
## applicant income
sns.boxplot(loan['ApplicantIncome'])
plt.show()

# %%
Q1 = loan['ApplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['ApplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 2864.0
# Q3 is 5060.0

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 2196.0

# %%
lwbound = Q1 - 1.5 * IQR
print(lwbound)

upbound = Q3 + 1.5 * IQR
print(upbound)
# Out:
# -430.0
# 8354.0

# %%
outliers = loan[(loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound)]
outliers
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 8    LP001059    Male     Yes          2      Graduate            No
# 13   LP001094    Male     Yes          2      Graduate            No
# 18   LP001108    Male     Yes          0      Graduate            No
# 81   LP001428    Male     Yes         3+      Graduate            No
# 83   LP001446    Male     Yes          0      Graduate            No
# 91   LP001483    Male     Yes         3+      Graduate            No
# 98   LP001517    Male     Yes         3+      Graduate            No
# 124  LP001655  Female      No          0      Graduate            No
# 143  LP001791    Male     Yes          0      Graduate           Yes
# 144  LP001794    Male     Yes          2      Graduate           Yes
# 145  LP001797  Female      No          0      Graduate            No
# 147  LP001817    Male      No          0  Not Graduate           Yes
# 179  LP002017    Male     Yes         3+      Graduate            No
# ...

# %%
median_applicant_income = loan['ApplicantIncome'].median()
median_applicant_income
# Out:
# 3786.0

# %%
loan['ApplicantIncome'] = np.where((loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound), median_applicant_income, loan['ApplicantIncome'])

loan['ApplicantIncome'] = np.where(loan['ApplicantIncome'] < 1000 , median_applicant_income, loan['ApplicantIncome'])

# %%
sns.boxplot(loan['ApplicantIncome'])
plt.show()

# %%
Q1 = loan['ApplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")
Q3 = loan['ApplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
IQR = Q3 - Q1
print(f"IQR is {IQR}")
lwbound = Q1 - 1.5 * IQR
print(lwbound)

upbound = Q3 + 1.5 * IQR
print(upbound)
outliers = loan[(loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound)]
outliers
median_applicant_income = loan['ApplicantIncome'].median()
median_applicant_income
loan['ApplicantIncome'] = np.where((loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound), median_applicant_income, loan['ApplicantIncome'])

loan['ApplicantIncome'] = np.where(loan['ApplicantIncome'] < 1000 , median_applicant_income, loan['ApplicantIncome'])
sns.boxplot(loan['ApplicantIncome'])
plt.show()
# Out:
# Q1 is 2915.5
# Q3 is 4506.5
# IQR is 1591.0
# 529.0
# 6893.0

# %%
Q1 = loan['ApplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")
Q3 = loan['ApplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
IQR = Q3 - Q1
print(f"IQR is {IQR}")
lwbound = Q1 - 1.5 * IQR
print(lwbound)

upbound = Q3 + 1.5 * IQR
print(upbound)
outliers = loan[(loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound)]
outliers
median_applicant_income = loan['ApplicantIncome'].median()
median_applicant_income
loan['ApplicantIncome'] = np.where((loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound), median_applicant_income, loan['ApplicantIncome'])

loan['ApplicantIncome'] = np.where(loan['ApplicantIncome'] < 1000 , median_applicant_income, loan['ApplicantIncome'])
sns.boxplot(loan['ApplicantIncome'])
plt.show()
# Out:
# Q1 is 2915.5
# Q3 is 4271.5
# IQR is 1356.0
# 881.5
# 6305.5

# %%
Q1 = loan['ApplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")
Q3 = loan['ApplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
IQR = Q3 - Q1
print(f"IQR is {IQR}")
lwbound = Q1 - 1.5 * IQR
print(lwbound)

upbound = Q3 + 1.5 * IQR
print(upbound)
outliers = loan[(loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound)]
outliers
median_applicant_income = loan['ApplicantIncome'].median()
median_applicant_income
loan['ApplicantIncome'] = np.where((loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound), median_applicant_income, loan['ApplicantIncome'])

loan['ApplicantIncome'] = np.where(loan['ApplicantIncome'] < 1000 , median_applicant_income, loan['ApplicantIncome'])
sns.boxplot(loan['ApplicantIncome'])
plt.show()
# Out:
# Q1 is 2915.5
# Q3 is 4143.0
# IQR is 1227.5
# 1074.25
# 5984.25

# %%
Q1 = loan['ApplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")
Q3 = loan['ApplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
IQR = Q3 - Q1
print(f"IQR is {IQR}")
lwbound = Q1 - 1.5 * IQR
print(lwbound)

upbound = Q3 + 1.5 * IQR
print(upbound)
outliers = loan[(loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound)]
outliers
median_applicant_income = loan['ApplicantIncome'].median()
median_applicant_income
loan['ApplicantIncome'] = np.where((loan['ApplicantIncome'] < lwbound) | (loan['ApplicantIncome'] > upbound), median_applicant_income, loan['ApplicantIncome'])

loan['ApplicantIncome'] = np.where(loan['ApplicantIncome'] < 1000 , median_applicant_income, loan['ApplicantIncome'])
sns.boxplot(loan['ApplicantIncome'])
plt.show()
# Out:
# Q1 is 2915.5
# Q3 is 4083.0
# IQR is 1167.5
# 1164.25
# 5834.25

# %%
sns.boxplot(loan['CoapplicantIncome'])
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
Q1 = loan['CoapplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['CoapplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 0.0
# Q3 is 2430.5

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 2430.5

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# -3645.75
# 6076.25

# %%
outliers = loan[(loan['CoapplicantIncome'] < lower_bound) | (loan['CoapplicantIncome'] > upper_bound)]
outliers
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 18   LP001108    Male     Yes          0      Graduate            No
# 25   LP001153    Male      No          0      Graduate            No
# 85   LP001452    Male     Yes          2      Graduate            No
# 123  LP001652    Male      No          0      Graduate            No
# 230  LP002294    Male      No          0      Graduate            No
# 237  LP002325    Male     Yes          2  Not Graduate            No
# 284  LP002570  Female     Yes          2      Graduate            No
# 351  LP002901    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 18            3786.0               7916       125.0             360.0
# 25            3786.0              24000       148.0             360.0
# 85            4635.0               8000       102.0             360.0
# ...

# %%
median_CoapplicantIncome = loan['CoapplicantIncome'].median()
print(median_CoapplicantIncome)
# Out:
# 1025.0

# %%
loan['CoapplicantIncome'] = np.where((loan['CoapplicantIncome'] < lower_bound) | (loan['CoapplicantIncome'] > upper_bound), median_CoapplicantIncome, loan['CoapplicantIncome'])

loan['CoapplicantIncome'] = np.where(loan['CoapplicantIncome'] < 1000, median_CoapplicantIncome, loan['CoapplicantIncome'])

# %%
sns.boxplot(loan['CoapplicantIncome'])
plt.show()

# %%
Q1 = loan['CoapplicantIncome'].quantile(0.25)
print(f"Q1 is {Q1}")

Q3 = loan['CoapplicantIncome'].quantile(0.75)
print(f"Q3 is {Q3}")
# Out:
# Q1 is 1025.0
# Q3 is 2368.5

# %%
IQR = Q3 - Q1
print(f"IQR is {IQR}")
# Out:
# IQR is 1343.5

# %%
lower_bound = Q1 - 1.5 * IQR
print(lower_bound)

upper_bound = Q3 + 1.5 * IQR
print(upper_bound)
# Out:
# -990.25
# 4383.75

# %%
loan['CoapplicantIncome'] = np.where(loan['CoapplicantIncome'] < lower_bound, lower_bound, loan['CoapplicantIncome'])
loan['CoapplicantIncome'] = np.where(loan['CoapplicantIncome'] > upper_bound, upper_bound, loan['CoapplicantIncome'])

# %%
sns.boxplot(loan['CoapplicantIncome'])
plt.show()

# %%
# Histograms: Plot the frequency distribution of key numeric variables
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
sns.histplot(loan['ApplicantIncome'], kde=True)
plt.title('Applicant Income Distribution')

plt.subplot(2, 3, 2)
sns.histplot(loan['CoapplicantIncome'], kde=True)
plt.title('Coapplicant Income Distribution')

plt.subplot(2, 3, 3)
sns.histplot(loan['LoanAmount'], kde=True)
plt.title('Loan Amount Distribution')

plt.subplot(2, 3, 4)
sns.histplot(loan['Loan_Amount_Term'], kde=True)
plt.title('Loan Amount Term Distribution')

plt.subplot(2, 3, 5)
sns.histplot(loan['Credit_History'], kde=True)
plt.title('Credit History Distribution')

plt.subplot(2, 3, 6)
sns.histplot(loan['Dependents'], kde=True)
plt.title('Dependents Distribution')

plt.tight_layout()
plt.show()

# %%
# Identify potential outliers and visualize the spread of data.
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
sns.boxplot(x=loan['ApplicantIncome'], color='skyblue')
plt.title('Applicant Income')

plt.subplot(2, 2, 2)
sns.boxplot(x=loan['CoapplicantIncome'], color='lightcoral')
plt.title('Coapplicant Income')

plt.subplot(2, 2, 3)
sns.boxplot(x=loan['LoanAmount'], color='lightgreen')
plt.title('Loan Amount')

plt.subplot(2, 2, 4)
sns.boxplot(x=loan['Loan_Amount_Term'], color='gold')
plt.title('Loan Amount Term')

plt.tight_layout()
plt.show()

# Violin plots for visualizing data spread and potential outliers
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
sns.violinplot(x=loan['ApplicantIncome'], color='skyblue')
plt.title('Applicant Income')

plt.subplot(2, 2, 2)
sns.violinplot(x=loan['CoapplicantIncome'], color='lightcoral')
plt.title('Coapplicant Income')

plt.subplot(2, 2, 3)
sns.violinplot(x=loan['LoanAmount'], color='lightgreen')
plt.title('Loan Amount')

plt.subplot(2, 2, 4)
sns.violinplot(x=loan['Loan_Amount_Term'], color='gold')
plt.title('Loan Amount Term')

plt.tight_layout()
plt.show()

# %%
#Bar Charts: Visualize the frequency distribution of categorical variables.
plt.figure(figsize=(6, 4))
loan['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()

# Bar chart for Married
plt.figure(figsize=(6, 4))
loan['Married'].value_counts().plot(kind='bar')
plt.xlabel('Married')
plt.ylabel('Count')
plt.title('Distribution of Marital Status')
plt.show()

# Bar chart for Self_Employed
plt.figure(figsize=(6, 4))
loan['Self_Employed'].value_counts().plot(kind='bar')
plt.xlabel('Self Employed')
plt.ylabel('Count')
plt.title('Distribution of Self Employment Status')
plt.show()

# Bar chart for Education
plt.figure(figsize=(6, 4))
loan['Education'].value_counts().plot(kind='bar')
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Distribution of Education Level')
plt.show()

# Bar chart for Property_Area
plt.figure(figsize=(6, 4))
loan['Property_Area'].value_counts().plot(kind='bar')
plt.xlabel('Property Area')
plt.ylabel('Count')
plt.title('Distribution of Property Area')
plt.show()

# %%
#Pie Charts: Represent the composition of categorical variables.
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
loan['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightcoral'])
plt.title('Gender Distribution')

plt.subplot(2, 3, 2)
loan['Married'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'lightpink'])
plt.title('Marital Status Distribution')

plt.subplot(2, 3, 3)
loan['Education'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['gold', 'lightblue'])
plt.title('Education Distribution')

plt.subplot(2, 3, 4)
loan['Self_Employed'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgray', 'orange'])
plt.title('Self-Employed Distribution')

plt.subplot(2, 3, 5)
loan['Property_Area'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'lightblue', 'lightcoral'])
plt.title('Property Area Distribution')

plt.tight_layout()
plt.show()

# %%
#Create scatter plots to explore relationships between pairs of numeric variables with green colour
plt.figure(figsize=(8, 6))
plt.scatter(loan['ApplicantIncome'], loan['LoanAmount'], c='green')
plt.xlabel('Applicant Income')
plt.ylabel('Loan Amount')
plt.title('Applicant Income vs Loan Amount')
plt.show()

# Scatter plot for CoapplicantIncome vs LoanAmount
plt.figure(figsize=(8, 6))
plt.scatter(loan['CoapplicantIncome'], loan['LoanAmount'], c='green')
plt.xlabel('Coapplicant Income')
plt.ylabel('Loan Amount')
plt.title('Coapplicant Income vs Loan Amount')
plt.show()

# %%
#Use pair plots (scatter matrix) to visualize interactions between  multiple numeric variables
sns.pairplot(loan[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']], plot_kws={'color': 'gray'})
plt.show()

# %%
#Investigate the relationship between categorical and numeric variables violin plots.
plt.figure(figsize=(8, 6))
sns.violinplot(x='Gender', y='LoanAmount', data=loan)
plt.xlabel('Gender')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Distribution by Gender')
plt.show()

# Violin plot for Married vs LoanAmount
plt.figure(figsize=(8, 6))
sns.violinplot(x='Married', y='LoanAmount', data=loan)
plt.xlabel('Married')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Distribution by Marital Status')
plt.show()

# Violin plot for Self_Employed vs LoanAmount
plt.figure(figsize=(8, 6))
sns.violinplot(x='Self_Employed', y='LoanAmount', data=loan)
plt.xlabel('Self Employed')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Distribution by Self Employment Status')
plt.show()

# Violin plot for Education vs LoanAmount
plt.figure(figsize=(8, 6))
sns.violinplot(x='Education', y='LoanAmount', data=loan)
plt.xlabel('Education')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Distribution by Education Level')
plt.show()

# Violin plot for Property_Area vs LoanAmount
plt.figure(figsize=(8, 6))
sns.violinplot(x='Property_Area', y='LoanAmount', data=loan)
plt.xlabel('Property Area')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Distribution by Property Area')
plt.show()

# %%
# Perform a correlation analysis to identify relationships between numeric variables
numeric_loan = loan.select_dtypes(include=['number'])
correlation_matrix = numeric_loan.corr()

# Create a heatmap to visualize correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#Create a stacked bar chart to show the distribution of categorical variables across multiple categories
gender_married = pd.crosstab(loan['Gender'], loan['Married'])
gender_married.plot(kind='bar', stacked=True, color=['skyblue', 'lightcoral'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender and Marital Status')
plt.legend(title='Married')
plt.show()

# Stacked Bar Chart for Education and Self_Employed
education_selfemp = pd.crosstab(loan['Education'], loan['Self_Employed'])
education_selfemp.plot(kind='bar', stacked=True, color=['lightgreen', 'lightpink'])
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Distribution of Education and Self-Employment')
plt.legend(title='Self-Employed')
plt.show()
